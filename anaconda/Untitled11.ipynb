# %%
n = int(input())
c = int(input())
l=[]
l1=[]
for i in range(0,n):
    ele =int(input())
    l.append(ele)
for i in range(0,n):
    ele = int(input())
    l1.append(ele)
sv=sw=s1=s =0
while(sw <=c):
    m = max(l)
    ind = l.index(m)
    s1 = sv
    s= sw
    sv+=l[ind]
    sw +=l1[ind]
    del l[ind]
    del l1[ind]
    if(sw>c):
        break
print(s1)
