# %%
l=list('HELLO')
p=l[0],l[-1],l[1:3]
'a={0},b={1},c={2}'.format(*p)
# Out:
# "a=H,b=O,c=['E', 'L']"

# %%
a='a'
for a in ['S','a','m','p','l','e']:
    print('hey')
# Out:
# hey
# hey
# hey
# hey
# hey
# hey
