# %%
def digit():
    i=int(input())
    digit=i%10
    print(digit)
digit()
# Out:
# 12
# 2

# %%
s="GEC"
print(s*3,end=" ")
# Out:
# GECGECGEC

# %%
x = 'This particular Monday has been the Tuesday of Wednesday. When Peoples and students thought it was Sunday'
a=x.split(' ')
for i in a:
    if(i.strip('.').endswith('day')):
        print(i)
# Out:
# Monday
# Tuesday
# Wednesday.
# Sunday
