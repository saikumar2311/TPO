# %%
n = 6
arr= [7,6,8,6,1,1]
j = su=0
os= []
while(j<n):
    m = min(arr)
    ind = arr.index(m)
    if(len(arr) == 2):
        os.append(sum(arr))
        break
    
    if(ind == len(arr)):
        su = m+arr[ind-1]
        del arr[ind]
        del arr[ind-1]
        arr.insert(ind,su)
        os.append(su)
        print(arr)
        
              
    elif(ind == len(arr)-2 ):
        if(m == arr[ind+1]):  #12 22 17
            su = m+arr[ind+1] #34
            del arr[ind]      
            del arr[ind]
            arr.insert(ind+1,su)
            os.append(su)
            print(arr)
        else:
            su = m+arr[ind+1] #34
            del arr[ind]      
            del arr[ind]
            arr.insert(ind+1,su)
            os.append(su)
            print(arr)
            
    elif(ind == len(arr)-1 ):
        su = m+arr[ind-1]
        os.append(su)
        del arr[ind]
        del arr[ind-1]
        arr.insert(ind,su)
        print(arr)
    elif(arr[ind+1]>m and arr[ind-1]>m):
        if(arr[ind+1]>arr[ind-1]):
            su = m+arr[ind-1]
            os.append(su)
           # print(arr[ind])
            del arr[ind]
            #print(arr[ind-1])
            del arr[ind-1]
            arr.insert(ind-1,su)
            print(arr)
    elif(m == arr[ind+1]):
        su = m+arr[ind+1]
        del arr[ind]
        del arr[ind]
        arr.insert(ind+1,su)
        print(arr)
        os.append(su)
    j+=1
print(sum(os))
# Out:
# [7, 6, 8, 6, 2]
# [7, 6, 8, 8]
# [13, 8, 8]
# [13, 16]
# 68
